# %% [markdown]
# <a href="https://colab.research.google.com/github/829797siva/matlpotlib/blob/main/Line_Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LINE PLOT:
#
# shows data trends over continuous intervals

# %%
#import the libraires
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[2,4,6,8,10]
plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Line Plot')
plt.show()
